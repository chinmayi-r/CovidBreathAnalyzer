# %%
import shutil,os
from pathlib import Path
import pandas as pd
import numpy as np

# %%
csvpath = r'C:\Users\Chinmayi\Anaconda\Datasets\Respiratory_Sound_Database\csv_all_data.csv'
df = pd.read_csv(csvpath, header = None)
df
# Out:
#                               0          1
# 0    101_1b1_Al_sc_Meditron.wav       URTI
# 1    101_1b1_Pr_sc_Meditron.wav       URTI
# 2    102_1b1_Ar_sc_Meditron.wav    Healthy
# 3    103_2b2_Ar_mc_LittC2SE.wav     Asthma
# 4    104_1b1_Al_sc_Litt3200.wav       COPD
# ..                          ...        ...
# 915  224_1b2_Al_sc_Meditron.wav    Healthy
# 916  225_1b1_Pl_sc_Meditron.wav    Healthy
# 917  226_1b1_Al_sc_Meditron.wav  Pneumonia
# 918  226_1b1_Ll_sc_Meditron.wav  Pneumonia
# 919  226_1b1_Pl_sc_LittC2SE.wav  Pneumonia
#
# [920 rows x 2 columns]

# %%
for x in range(0,len(df[0])):
    file = df[0][x]
    file = file[0:-4]+'.png'
    spath = Path('C:/Users/Chinmayi/Anaconda/Datasets/Respiratory_Sound_Database/amplitude_spectograms/')
    path_start = spath/file
    path_end = spath/df[1][x]
    shutil.move(str(path_start),str(path_end))
    print(path_start)
    print(path_end)
    print()
# Out:
# C:\Users\Chinmayi\Anaconda\Datasets\Respiratory_Sound_Database\amplitude_spectograms\101_1b1_Al_sc_Meditron.png
# C:\Users\Chinmayi\Anaconda\Datasets\Respiratory_Sound_Database\amplitude_spectograms\URTI
#
# C:\Users\Chinmayi\Anaconda\Datasets\Respiratory_Sound_Database\amplitude_spectograms\101_1b1_Pr_sc_Meditron.png
# C:\Users\Chinmayi\Anaconda\Datasets\Respiratory_Sound_Database\amplitude_spectograms\URTI
#
# C:\Users\Chinmayi\Anaconda\Datasets\Respiratory_Sound_Database\amplitude_spectograms\102_1b1_Ar_sc_Meditron.png
# C:\Users\Chinmayi\Anaconda\Datasets\Respiratory_Sound_Database\amplitude_spectograms\Healthy
#
# C:\Users\Chinmayi\Anaconda\Datasets\Respiratory_Sound_Database\amplitude_spectograms\103_2b2_Ar_mc_LittC2SE.png
# C:\Users\Chinmayi\Anaconda\Datasets\Respiratory_Sound_Database\amplitude_spectograms\Asthma
#
# C:\Users\Chinmayi\Anaconda\Datasets\Respiratory_Sound_Database\amplitude_spectograms\104_1b1_Al_sc_Litt3200.png
# ...
