# %%
import pandas as pd
import numpy as np

# %%
txtpath = r'C:\Users\Chinmayi\Anaconda\Datasets\Respiratory_Sound_Database\audio_and_txt_files\file_names.txt'
wav_files = pd.read_csv(txtpath,sep='\n', header=None, names=['files'])
df = wav_files.copy()
wav_files
# Out:
#                           files
# 0    101_1b1_Al_sc_Meditron.wav
# 1    101_1b1_Pr_sc_Meditron.wav
# 2    102_1b1_Ar_sc_Meditron.wav
# 3    103_2b2_Ar_mc_LittC2SE.wav
# 4    104_1b1_Al_sc_Litt3200.wav
# ..                          ...
# 915  224_1b2_Al_sc_Meditron.wav
# 916  225_1b1_Pl_sc_Meditron.wav
# 917  226_1b1_Al_sc_Meditron.wav
# 918  226_1b1_Ll_sc_Meditron.wav
# 919  226_1b1_Pl_sc_LittC2SE.wav
#
# [920 rows x 1 columns]

# %%
csvpath = r'C:\Users\Chinmayi\Anaconda\Datasets\Respiratory_Sound_Database\patient_diagnosis.csv'
pdata = pd.read_csv(csvpath)
pdata['no'] = pd.to_numeric(pdata['no'])
pdata = pdata.set_index('no')
pdata
# Out:
#      diagnosis
# no
# 101       URTI
# 102    Healthy
# 103     Asthma
# 104       COPD
# 105       URTI
# ..         ...
# 222       COPD
# 223       COPD
# 224    Healthy
# 225    Healthy
# 226  Pneumonia
#
# [126 rows x 1 columns]

# %%
l = []
for i in wav_files['files']:
    for n in range(101,227):
        if str(n)==i[0:3]:
            l += [pdata.iloc[n-101][0]]
            break

# %%
l
# Out:
# ['URTI',
#  'URTI',
#  'Healthy',
#  'Asthma',
#  'COPD',
#  'COPD',
#  'COPD',
#  'COPD',
#  'COPD',
#  'COPD',
#  'URTI',
#  'COPD',
#  'COPD',
#  'COPD',
#  'COPD',
#  'COPD',
#  'COPD',
#  'COPD',
#  'COPD',
#  'COPD',
#  'COPD',
#  'COPD',
#  'COPD',
#  'COPD',
#  'COPD',
#  'COPD',
#  'COPD',
#  'COPD',
#  'COPD',
#  'COPD',
#  'COPD',
#  'COPD',
#  'COPD',
#  'COPD',
#  'COPD',
#  'COPD',
#  'COPD',
#  'COPD',
#  'COPD',
#  'COPD',
#  'COPD',
#  'LRTI',
#  'COPD',
#  'COPD',
#  'COPD',
#  'COPD',
#  'COPD',
#  'COPD',
#  'COPD',
#  'COPD',
#  'COPD',
#  'COPD',
#  'COPD',
#  'Bronchiectasis',
#  'Bronchiectasis',
#  'COPD',
#  'COPD',
#  'COPD',
#  'COPD',
#  'COPD',
#  'COPD',
#  'COPD',
#  'COPD',
#  'COPD',
#  'COPD',
#  'COPD',
#  'COPD',
#  'COPD',
#  'COPD',
#  'COPD',
#  'COPD',
#  'LRTI',
#  'Bronchiectasis',
#  'Bronchiectasis',
#  'COPD',
#  'COPD',
#  'COPD',
#  'COPD',
#  'COPD',
#  'COPD',
#  'COPD',
#  'COPD',
#  'URTI',
#  'COPD',
#  'COPD',
#  'COPD',
# ...

# %%
df['diagnosis'] = l
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-2a7c8f35e43e> in <module>
# ----> 1 l = df['diagnosis']
#
# NameError: name 'df' is not defined

# %%
l
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-cc24da8ff90c> in <module>
# ----> 1 l.unique()
#
# NameError: name 'l' is not defined

# %%
df.to_csv(path_or_buf = r'C:\Users\Chinmayi\Anaconda\Datasets\Respiratory_Sound_Database\all_data.csv', index=False)
